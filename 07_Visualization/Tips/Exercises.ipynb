# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv'

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv(url, sep=',')

# %%
tips.sample()
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day   time  size
# 119         119       24.08  2.92  Female     No  Thur  Lunch     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
del tips['Unnamed: 0']

# %%
tips.sample()
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 139       13.16  2.75  Female     No  Thur  Lunch     2

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
sns.histplot(data=tips,
            x='total_bill')
plt.show()

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
sns.scatterplot(data=tips,
               x='total_bill',
               y='tip')
plt.show()

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
tips['sizestr'] = tips.size.astype(str)

# %%
tips.sample()
# Out:
#     total_bill   tip   sex smoker  day    time  size sizestr
# 42       13.94  3.06  Male     No  Sun  Dinner     2    1708

# %%
sns.scatterplot(data=tips,
               x='total_bill',
               y='tip',
               hue='size')
plt.show()

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
billByDay = tips.groupby('day')['total_bill'].mean().reset_index()

# %%
sns.lineplot(data=billByDay,
               x='day',
               y='total_bill')
plt.show()

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.scatterplot(data=tips,
               x='tip',
               y='day',
               hue='sex')
plt.show()

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
billByDayTime = tips.groupby(['day', 'time'])['total_bill'].mean().reset_index()

# %%
sns.boxplot(data=tips,
           x='day',
           y='total_bill',
           hue='time')
plt.show()

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
sns.displot(data=tips,
            x='tip',
            col='time')

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
tips.sample()
# Out:
#      total_bill   tip     sex smoker   day   time  size sizestr
# 131       20.27  2.83  Female     No  Thur  Lunch     2    1708

# %%
sns.relplot(data=tips,
           x='total_bill',
           y='tip',
           col='sex',
           hue='smoker')
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
