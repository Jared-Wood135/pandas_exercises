# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv)

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv'

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic = pd.read_csv(url, sep=',')

# %%
titanic.sample()
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 269          270         1       1  Bissette, Miss. Amelia  female  35.0
#
#      SibSp  Parch    Ticket      Fare Cabin Embarked
# 269      0      0  PC 17760  135.6333   C99        S

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic = titanic.set_index('PassengerId')

# %%
titanic.sample()
# Out:
#              Survived  Pclass                    Name   Sex   Age  SibSp  \
# PassengerId
# 314                 0       3  Hendekovic, Mr. Ignjac  male  28.0      0
#
#              Parch  Ticket    Fare Cabin Embarked
# PassengerId
# 314              0  349243  7.8958   NaN        S

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
males = (titanic.Sex == 'male').sum()
females = (titanic.Sex == 'female').sum()
mf_proportion = [males, females]
plt.pie(mf_proportion, 
        labels=['Males', 'Females'], 
        explode=(0.05, 0),
        startangle=90,
        autopct='%1.1f%%')
plt.title('Percent Sex of Titanic', fontsize=20)
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
sns.lmplot(
data=titanic,
x='Fare',
y='Age',
hue='Sex',
fit_reg=False)
plt.show()

# %% [markdown]
# ### Step 7. How many people survived?

# %%
titanic.Survived.sum()
# Out:
# 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
temptitanic = titanic.Fare.sort_values()

# %%
plt.hist(temptitanic, ec='black')
plt.title('Fare Paid Histogram')
plt.xlabel('Fare')
plt.xlim(0, 600, 10)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.
